# %% [markdown]
# # Introdução Às Redes Neurais

# %% [markdown]
# ## Aula Introdutória - Artigo: Perceptrons: The First Neural Network

# %%
# %%HTML
# <a href="https://medium.com/data-science/perceptrons-the-first-neural-network-model-8b3ee4513757">Perceptrons: The First Neural Network Model</a>
# Out:
# <a href="https://medium.com/data-science/perceptrons-the-first-neural-network-model-8b3ee4513757">Perceptrons: The First Neural Network Model</a>

# %% [markdown]
# ### Rede Neural Multicamadas com Retropropagação

# %% [markdown]
# ![nn.jpg](attachment:41965c6a-a8dc-42fb-bd2c-be7950b74851.jpg)

# %%
import numpy as np

def activation_function(x):
 # return np.heaviside(x, 1)
 return 1 / (1 + np.exp(-x))



def deriv_activ_function(x):
  fx = activation_function(x)
  return fx * (1 - fx)

def mse_loss(y_true, y_pred):
  return ((y_true - y_pred) ** 2).mean()

class NeuralNetwork:
  
  def __init__(self):
    # Weights
    self.w1 = np.random.normal()
    self.w2 = np.random.normal()
    self.w3 = np.random.normal()
    self.w4 = np.random.normal()
    self.w5 = np.random.normal()
    self.w6 = np.random.normal()   
    self.w7 = np.random.normal()
    self.w8 = np.random.normal()
    self.w9 = np.random.normal()

    # Biases
    self.b1 = np.random.normal()
    self.b2 = np.random.normal()
    self.b3 = np.random.normal()
    self.b4 = np.random.normal()

  def feedforward(self, x):

    h1 = activation_function(self.w1 * x[0] + self.w2 * x[1] + self.b1)
    h2 = activation_function(self.w3 * x[0] + self.w4 * x[1] + self.b2)
    h3 = activation_function(self.w5 * x[0] + self.w6 * x[1] + self.b3)
    o1 = activation_function(self.w7 * h1 + self.w8 * h2 + self.w9*h3+self.b4)
    return o1

  def train(self, data, y_trues,loss):
    
    alpha = 0.1
    epochs = 2000 # number of times to loop through the entire dataset
    iloss=0

    for epoch in range(epochs):
      for x, y_true in zip(data, y_trues):
        # Feedforward 
        sum_h1 = self.w1 * x[0] + self.w2 * x[1] + self.b1
        h1 = activation_function(sum_h1)

        sum_h2 = self.w3 * x[0] + self.w4 * x[1] + self.b2
        h2 = activation_function(sum_h2)

        sum_h3 = self.w5 * x[0] + self.w6 * x[1] + self.b3
        h3 = activation_function(sum_h3)

        sum_o1 = self.w7 * h1 + self.w8 * h2 + self.w9*h3 + self.b4
        o1 = activation_function(sum_o1)
        y_pred = o1

        # --- Calculate partial derivatives.
        d_L_d_ypred = -2 * (y_true - y_pred)

        # Neuron o1
        d_ypred_d_w7 = h1 * deriv_activ_function(sum_o1)
        d_ypred_d_w8 = h2 * deriv_activ_function(sum_o1)
        d_ypred_d_w9 = h3 * deriv_activ_function(sum_o1)
        d_ypred_d_b4 = deriv_activ_function(sum_o1)

        d_ypred_d_h1 = self.w7 * deriv_activ_function(sum_o1)
        d_ypred_d_h2 = self.w8 * deriv_activ_function(sum_o1)
        d_ypred_d_h3 = self.w9 * deriv_activ_function(sum_o1)

        # Neuron h1
        d_h1_d_w1 = x[0] * deriv_activ_function(sum_h1)
        d_h1_d_w2 = x[1] * deriv_activ_function(sum_h1)
        d_h1_d_b1 = deriv_activ_function(sum_h1)

        # Neuron h2
        d_h2_d_w3 = x[0] * deriv_activ_function(sum_h2)
        d_h2_d_w4 = x[1] * deriv_activ_function(sum_h2)
        d_h2_d_b2 = deriv_activ_function(sum_h2)

        # Neuron h3
        d_h3_d_w5 = x[0] * deriv_activ_function(sum_h3)
        d_h3_d_w6 = x[1] * deriv_activ_function(sum_h3)
        d_h3_d_b3 = deriv_activ_function(sum_h3)

        # --- Update weights and biases
        # Neuron h1
        self.w1 -= alpha * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w1
        self.w2 -= alpha * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w2
        self.b1 -= alpha * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_b1

        # Neuron h2
        self.w3 -= alpha * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w3
        self.w4 -= alpha * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w4
        self.b2 -= alpha * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_b2

        # Neuron h3
        self.w5 -= alpha * d_L_d_ypred * d_ypred_d_h3 * d_h3_d_w5
        self.w6 -= alpha * d_L_d_ypred * d_ypred_d_h3 * d_h3_d_w6
        self.b3 -= alpha * d_L_d_ypred * d_ypred_d_h3 * d_h3_d_b3

        # Neuron o1
        self.w7 -= alpha * d_L_d_ypred * d_ypred_d_w7
        self.w8 -= alpha * d_L_d_ypred * d_ypred_d_w8
        self.w9 -= alpha * d_L_d_ypred * d_ypred_d_w9
        self.b4 -= alpha * d_L_d_ypred * d_ypred_d_b4

      # --- Calculate total loss at the end of each epoch
      if epoch % 10 == 0:
        y_preds = np.apply_along_axis(self.feedforward, 1, data)
        print('y_preds=',np.round(y_preds))
        loss[iloss] = mse_loss(y_trues, y_preds)
        
        print("Epoch %d loss: %.3f" % (epoch, loss[iloss]))
        iloss=iloss+1
        
        

# Data
data = np.array([
  [0, 0], 
  [0,1],  
  [1,0],   
  [1,1], 
])
y_trues = np.array([
  0, 
  1, 
  1,
  0, 
])

# Train the NNetwork

loss=np.zeros(200)
network = NeuralNetwork()
network.train(data, y_trues,loss)
iep=np.arange(200)
import matplotlib.pyplot as plt
plt.title('Loss vs. Epochs')
plt.plot(iep,loss)
plt.xlabel('Epochs/10')
plt.ylabel('Loss')
# Out:
# y_preds= [1. 1. 1. 1.]
# Epoch 0 loss: 0.352
# y_preds= [1. 1. 1. 1.]
# Epoch 10 loss: 0.284
# y_preds= [1. 1. 1. 1.]
# Epoch 20 loss: 0.257
# y_preds= [0. 1. 0. 1.]
# Epoch 30 loss: 0.253
# y_preds= [0. 1. 0. 1.]
# Epoch 40 loss: 0.252
# y_preds= [0. 1. 0. 1.]
# Epoch 50 loss: 0.251
# y_preds= [0. 1. 0. 1.]
# Epoch 60 loss: 0.251
# y_preds= [0. 1. 0. 1.]
# Epoch 70 loss: 0.251
# y_preds= [0. 1. 0. 1.]
# Epoch 80 loss: 0.251
# y_preds= [0. 1. 0. 1.]
# Epoch 90 loss: 0.251
# y_preds= [0. 1. 0. 1.]
# Epoch 100 loss: 0.251
# y_preds= [0. 1. 0. 1.]
# Epoch 110 loss: 0.250
# y_preds= [0. 1. 0. 1.]
# Epoch 120 loss: 0.250
# y_preds= [0. 1. 0. 1.]
# Epoch 130 loss: 0.250
# y_preds= [0. 1. 0. 1.]
# Epoch 140 loss: 0.250
# y_preds= [0. 1. 0. 1.]
# Epoch 150 loss: 0.250
# y_preds= [0. 1. 0. 1.]
# Epoch 160 loss: 0.250
# y_preds= [0. 1. 0. 1.]
# Epoch 170 loss: 0.250
# y_preds= [0. 1. 0. 1.]
# Epoch 180 loss: 0.250
# y_preds= [0. 1. 0. 1.]
# Epoch 190 loss: 0.250
# y_preds= [0. 1. 0. 1.]
# Epoch 200 loss: 0.250
# y_preds= [0. 1. 0. 0.]
# Epoch 210 loss: 0.250
# y_preds= [0. 1. 0. 0.]
# Epoch 220 loss: 0.250
# y_preds= [0. 1. 0. 0.]
# Epoch 230 loss: 0.250
# y_preds= [0. 1. 0. 0.]
# Epoch 240 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 250 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 260 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 270 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 280 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 290 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 300 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 310 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 320 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 330 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 340 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 350 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 360 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 370 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 380 loss: 0.250
# y_preds= [1. 1. 0. 0.]
# Epoch 390 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 400 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 410 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 420 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 430 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 440 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 450 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 460 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 470 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 480 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 490 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 500 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 510 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 520 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 530 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 540 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 550 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 560 loss: 0.249
# y_preds= [1. 1. 0. 0.]
# Epoch 570 loss: 0.248
# y_preds= [1. 1. 0. 0.]
# Epoch 580 loss: 0.248
# y_preds= [1. 1. 0. 0.]
# Epoch 590 loss: 0.248
# y_preds= [1. 1. 0. 0.]
# Epoch 600 loss: 0.248
# y_preds= [1. 1. 1. 0.]
# Epoch 610 loss: 0.248
# y_preds= [0. 1. 1. 0.]
# Epoch 620 loss: 0.248
# y_preds= [0. 1. 1. 0.]
# Epoch 630 loss: 0.248
# y_preds= [0. 1. 1. 0.]
# Epoch 640 loss: 0.247
# y_preds= [0. 1. 1. 0.]
# Epoch 650 loss: 0.247
# y_preds= [0. 1. 1. 0.]
# Epoch 660 loss: 0.247
# y_preds= [0. 1. 1. 0.]
# Epoch 670 loss: 0.247
# y_preds= [0. 1. 1. 0.]
# Epoch 680 loss: 0.247
# y_preds= [0. 1. 1. 0.]
# Epoch 690 loss: 0.246
# y_preds= [0. 1. 1. 1.]
# Epoch 700 loss: 0.246
# y_preds= [0. 1. 1. 1.]
# Epoch 710 loss: 0.246
# y_preds= [0. 1. 1. 1.]
# Epoch 720 loss: 0.245
# y_preds= [0. 1. 1. 1.]
# Epoch 730 loss: 0.245
# y_preds= [0. 1. 1. 1.]
# Epoch 740 loss: 0.245
# y_preds= [0. 1. 1. 1.]
# Epoch 750 loss: 0.244
# y_preds= [0. 1. 1. 1.]
# Epoch 760 loss: 0.244
# y_preds= [0. 1. 1. 1.]
# Epoch 770 loss: 0.243
# y_preds= [0. 1. 1. 1.]
# Epoch 780 loss: 0.243
# y_preds= [0. 1. 1. 1.]
# Epoch 790 loss: 0.242
# y_preds= [0. 1. 1. 1.]
# Epoch 800 loss: 0.242
# y_preds= [0. 1. 1. 1.]
# Epoch 810 loss: 0.241
# y_preds= [0. 1. 1. 1.]
# Epoch 820 loss: 0.240
# y_preds= [0. 1. 1. 1.]
# Epoch 830 loss: 0.239
# y_preds= [0. 1. 1. 1.]
# Epoch 840 loss: 0.238
# y_preds= [0. 1. 1. 1.]
# Epoch 850 loss: 0.238
# y_preds= [0. 1. 1. 0.]
# Epoch 860 loss: 0.237
# y_preds= [0. 1. 1. 0.]
# Epoch 870 loss: 0.235
# y_preds= [0. 1. 1. 0.]
# Epoch 880 loss: 0.234
# y_preds= [0. 1. 1. 0.]
# Epoch 890 loss: 0.233
# y_preds= [0. 1. 1. 0.]
# Epoch 900 loss: 0.232
# y_preds= [0. 1. 1. 0.]
# Epoch 910 loss: 0.230
# y_preds= [0. 1. 1. 0.]
# Epoch 920 loss: 0.229
# y_preds= [0. 1. 1. 0.]
# Epoch 930 loss: 0.227
# y_preds= [0. 1. 1. 0.]
# Epoch 940 loss: 0.225
# y_preds= [0. 1. 1. 0.]
# Epoch 950 loss: 0.223
# y_preds= [0. 1. 1. 0.]
# Epoch 960 loss: 0.221
# y_preds= [0. 1. 1. 0.]
# Epoch 970 loss: 0.219
# y_preds= [0. 1. 1. 0.]
# Epoch 980 loss: 0.216
# y_preds= [0. 1. 1. 0.]
# Epoch 990 loss: 0.214
# y_preds= [0. 1. 1. 0.]
# Epoch 1000 loss: 0.211
# y_preds= [0. 1. 1. 0.]
# Epoch 1010 loss: 0.208
# y_preds= [0. 1. 1. 0.]
# Epoch 1020 loss: 0.205
# y_preds= [0. 1. 1. 0.]
# Epoch 1030 loss: 0.202
# y_preds= [0. 1. 1. 0.]
# Epoch 1040 loss: 0.199
# y_preds= [0. 1. 1. 0.]
# Epoch 1050 loss: 0.195
# y_preds= [0. 1. 1. 0.]
# Epoch 1060 loss: 0.192
# y_preds= [0. 1. 1. 0.]
# Epoch 1070 loss: 0.188
# y_preds= [0. 1. 1. 0.]
# Epoch 1080 loss: 0.184
# y_preds= [0. 1. 1. 0.]
# Epoch 1090 loss: 0.180
# y_preds= [0. 1. 1. 0.]
# Epoch 1100 loss: 0.176
# y_preds= [0. 1. 1. 0.]
# Epoch 1110 loss: 0.172
# y_preds= [0. 1. 1. 0.]
# Epoch 1120 loss: 0.168
# y_preds= [0. 1. 1. 0.]
# Epoch 1130 loss: 0.163
# y_preds= [0. 1. 1. 0.]
# Epoch 1140 loss: 0.159
# y_preds= [0. 1. 1. 0.]
# Epoch 1150 loss: 0.154
# y_preds= [0. 1. 1. 0.]
# Epoch 1160 loss: 0.150
# y_preds= [0. 1. 1. 0.]
# Epoch 1170 loss: 0.145
# y_preds= [0. 1. 1. 0.]
# Epoch 1180 loss: 0.140
# y_preds= [0. 1. 1. 0.]
# Epoch 1190 loss: 0.136
# y_preds= [0. 1. 1. 0.]
# Epoch 1200 loss: 0.131
# y_preds= [0. 1. 1. 0.]
# Epoch 1210 loss: 0.127
# y_preds= [0. 1. 1. 0.]
# Epoch 1220 loss: 0.122
# y_preds= [0. 1. 1. 0.]
# Epoch 1230 loss: 0.118
# y_preds= [0. 1. 1. 0.]
# Epoch 1240 loss: 0.114
# y_preds= [0. 1. 1. 0.]
# Epoch 1250 loss: 0.109
# y_preds= [0. 1. 1. 0.]
# Epoch 1260 loss: 0.105
# y_preds= [0. 1. 1. 0.]
# Epoch 1270 loss: 0.101
# y_preds= [0. 1. 1. 0.]
# Epoch 1280 loss: 0.098
# y_preds= [0. 1. 1. 0.]
# Epoch 1290 loss: 0.094
# y_preds= [0. 1. 1. 0.]
# Epoch 1300 loss: 0.090
# y_preds= [0. 1. 1. 0.]
# Epoch 1310 loss: 0.087
# y_preds= [0. 1. 1. 0.]
# Epoch 1320 loss: 0.084
# y_preds= [0. 1. 1. 0.]
# Epoch 1330 loss: 0.080
# y_preds= [0. 1. 1. 0.]
# Epoch 1340 loss: 0.077
# y_preds= [0. 1. 1. 0.]
# Epoch 1350 loss: 0.075
# y_preds= [0. 1. 1. 0.]
# Epoch 1360 loss: 0.072
# y_preds= [0. 1. 1. 0.]
# Epoch 1370 loss: 0.069
# y_preds= [0. 1. 1. 0.]
# Epoch 1380 loss: 0.067
# y_preds= [0. 1. 1. 0.]
# Epoch 1390 loss: 0.064
# y_preds= [0. 1. 1. 0.]
# Epoch 1400 loss: 0.062
# y_preds= [0. 1. 1. 0.]
# Epoch 1410 loss: 0.060
# y_preds= [0. 1. 1. 0.]
# Epoch 1420 loss: 0.057
# y_preds= [0. 1. 1. 0.]
# Epoch 1430 loss: 0.055
# y_preds= [0. 1. 1. 0.]
# Epoch 1440 loss: 0.054
# y_preds= [0. 1. 1. 0.]
# Epoch 1450 loss: 0.052
# y_preds= [0. 1. 1. 0.]
# Epoch 1460 loss: 0.050
# y_preds= [0. 1. 1. 0.]
# Epoch 1470 loss: 0.048
# y_preds= [0. 1. 1. 0.]
# Epoch 1480 loss: 0.047
# y_preds= [0. 1. 1. 0.]
# Epoch 1490 loss: 0.045
# y_preds= [0. 1. 1. 0.]
# Epoch 1500 loss: 0.044
# y_preds= [0. 1. 1. 0.]
# Epoch 1510 loss: 0.042
# y_preds= [0. 1. 1. 0.]
# Epoch 1520 loss: 0.041
# y_preds= [0. 1. 1. 0.]
# Epoch 1530 loss: 0.040
# y_preds= [0. 1. 1. 0.]
# Epoch 1540 loss: 0.039
# y_preds= [0. 1. 1. 0.]
# Epoch 1550 loss: 0.038
# y_preds= [0. 1. 1. 0.]
# Epoch 1560 loss: 0.036
# y_preds= [0. 1. 1. 0.]
# Epoch 1570 loss: 0.035
# y_preds= [0. 1. 1. 0.]
# Epoch 1580 loss: 0.034
# y_preds= [0. 1. 1. 0.]
# Epoch 1590 loss: 0.033
# y_preds= [0. 1. 1. 0.]
# Epoch 1600 loss: 0.033
# y_preds= [0. 1. 1. 0.]
# Epoch 1610 loss: 0.032
# y_preds= [0. 1. 1. 0.]
# Epoch 1620 loss: 0.031
# y_preds= [0. 1. 1. 0.]
# Epoch 1630 loss: 0.030
# y_preds= [0. 1. 1. 0.]
# Epoch 1640 loss: 0.029
# y_preds= [0. 1. 1. 0.]
# Epoch 1650 loss: 0.029
# y_preds= [0. 1. 1. 0.]
# Epoch 1660 loss: 0.028
# y_preds= [0. 1. 1. 0.]
# Epoch 1670 loss: 0.027
# y_preds= [0. 1. 1. 0.]
# Epoch 1680 loss: 0.027
# y_preds= [0. 1. 1. 0.]
# Epoch 1690 loss: 0.026
# y_preds= [0. 1. 1. 0.]
# Epoch 1700 loss: 0.025
# y_preds= [0. 1. 1. 0.]
# Epoch 1710 loss: 0.025
# y_preds= [0. 1. 1. 0.]
# Epoch 1720 loss: 0.024
# y_preds= [0. 1. 1. 0.]
# Epoch 1730 loss: 0.024
# y_preds= [0. 1. 1. 0.]
# Epoch 1740 loss: 0.023
# y_preds= [0. 1. 1. 0.]
# Epoch 1750 loss: 0.023
# y_preds= [0. 1. 1. 0.]
# Epoch 1760 loss: 0.022
# y_preds= [0. 1. 1. 0.]
# Epoch 1770 loss: 0.022
# y_preds= [0. 1. 1. 0.]
# Epoch 1780 loss: 0.021
# y_preds= [0. 1. 1. 0.]
# Epoch 1790 loss: 0.021
# y_preds= [0. 1. 1. 0.]
# Epoch 1800 loss: 0.020
# y_preds= [0. 1. 1. 0.]
# Epoch 1810 loss: 0.020
# y_preds= [0. 1. 1. 0.]
# Epoch 1820 loss: 0.020
# y_preds= [0. 1. 1. 0.]
# Epoch 1830 loss: 0.019
# y_preds= [0. 1. 1. 0.]
# Epoch 1840 loss: 0.019
# y_preds= [0. 1. 1. 0.]
# Epoch 1850 loss: 0.018
# y_preds= [0. 1. 1. 0.]
# Epoch 1860 loss: 0.018
# y_preds= [0. 1. 1. 0.]
# Epoch 1870 loss: 0.018
# y_preds= [0. 1. 1. 0.]
# Epoch 1880 loss: 0.017
# y_preds= [0. 1. 1. 0.]
# Epoch 1890 loss: 0.017
# y_preds= [0. 1. 1. 0.]
# Epoch 1900 loss: 0.017
# y_preds= [0. 1. 1. 0.]
# Epoch 1910 loss: 0.017
# y_preds= [0. 1. 1. 0.]
# Epoch 1920 loss: 0.016
# y_preds= [0. 1. 1. 0.]
# Epoch 1930 loss: 0.016
# y_preds= [0. 1. 1. 0.]
# Epoch 1940 loss: 0.016
# y_preds= [0. 1. 1. 0.]
# Epoch 1950 loss: 0.015
# y_preds= [0. 1. 1. 0.]
# Epoch 1960 loss: 0.015
# y_preds= [0. 1. 1. 0.]
# Epoch 1970 loss: 0.015
# y_preds= [0. 1. 1. 0.]
# Epoch 1980 loss: 0.015
# y_preds= [0. 1. 1. 0.]
# Epoch 1990 loss: 0.014
# Text(0, 0.5, 'Loss')

# %% [markdown]
# Referências até aqui:
#
# [1] Michael Collins, Convergence Proof for the Perceptron Algorithm
#
# [2] https://www.geeksforgeeks.org/perceptron-convergence-theorem-in-neural-networks/
#
# [3]Rumelhart, D., Hinton, G. & Williams, R. Learning representations by back-propagating errors. Nature 323, 533–536 (1986). https://doi.org/10.1038/323533a0

# %% [markdown]
# ## Vetorização

# %% [markdown]
# Referências:
#
# [1]  Dr. Andy Thomas  Neural Networks Tutorial – A Pathway to Deep Learning :
# http://deeplearning.lipingyang.org/wp-content/uploads/2016/12/Neural-Networks-Tutorial-A-Pathway-to-Deep-Learning-Adventures-in-Machine-Learning.pdf
#
# [2]https://victorzhou.com/blog/intro-to-rnns/#73-gradients

# %% [markdown]
# Os dados de entrada devem ter o formato de matrizes x[$n_i$,$n_a$]
#     e y[$n_i$,$n_a$], onde $n_i$ é o número de dados de entrada em cada amostra e $n_a$ é o número de amostras.
# Assim, como exemplo, uma determinada rede com conexão densa possui $n_i$=2 dados de entrada e $n_a$=4. Considere ainda uma camada oculta com dois neurônios, e um único neurônio na camada de saída, havendo portanto uma saída para cada amostra. Portanto, temos as seguintes matrizes dimensionadas a seguir: $X[2,4],\, Y[1,4],\, W_h[2,2],\, W_o[1,2],\, b_h[2,1],\, e\, b_o[1,1]$.
# ![toy_nn.jpg](attachment:87ce24ff-a2b2-40b0-a039-5abff63742aa.jpg)
#
# ### Assim, na propagação direta (*feedforward*) podemos escrever que
#
# $Z_{h1}=W_{11}^hX_1+W_{12}^hX_2+b_{h1}$
#
# $Z_{h2}=W_{21}^hX_1+ W_{22}X_2+b_{h2}$. Na forma matricial,
#
# $Z_{[2,4]}^h=W_{[2,2]}^hX_{[2,4]}+b_{[2,1]}^h$. Na saída da camada escondida, podemos escrever que
#
# $H_{[2,4]}=f_a(Z^h)$, onde $H=\begin{bmatrix}
# h_1 \\
# h_2
# \end{bmatrix}=\begin{bmatrix}
# f_a(Z_{h1}) \\
# f_a(Z_{h2})
# \end{bmatrix}$, e $h_1$ e $h_2$ tem dimensões [1,4]. Finalmente, para a camada de saída
#
# $Z_{[1,4]}^o=\begin{bmatrix} w_{11}^o & w_{12}^o \end{bmatrix}\begin{bmatrix}
# h_1 \\
# h_2
# \end{bmatrix}+\begin{bmatrix}
# b_o \end{bmatrix}=W_{[1,2]}^oH_{[2,4]}+b_{[1,1]}^o$ e $ y_p=f_a(Z^o)$ com dimensões [1,4].
#
# ### Retropropagação (*backpropagation*)
#
# na camada de saída partimos do *array* $\frac{\partial{L}}{\partial{Y_p}}$,
#
# $\frac{\partial{L}}{\partial{Y_p}}_{[1,4]}=\begin{bmatrix} \frac{\partial{L}}{\partial{Y_{p1}}} & \frac{\partial{L}}{\partial{Y_{p2}}} & \frac{\partial{L}}{\partial{Y_{p3}}} & \frac{\partial{L}}{\partial{Y_{p4}}}\end{bmatrix}$,
#
# $\frac{\partial{L}}{\partial{W_{11}^o}}=\underbrace{\frac{\partial{L}}{\partial{Y_p}}\frac{\partial{y_p}}{\partial{Z^o}}}_{\frac{\partial{L}}{\partial{Z^o}}}\frac{\partial{Z^o}}{\partial{W_{11}^o}}=\frac{\partial{L}}{\partial{Y_p}}f_a'(Z^o)\frac{\partial{W_{11}^o h_1+W_{12}^o h_2}}{\partial{W_{11}^o}}=\frac{\partial{L}}{\partial{Y_p}}f_a'(Z^o)h_1$
#
# $\frac{\partial{L}}{\partial{W_{12}^o}}=\frac{\partial{L}}{\partial{Y_p}}f_a'(Z^o)h_2$
#
# e
#
# $\left[\frac{\partial{L}}{\partial{W^o}}\right]_{[1,2]}=\left[ \frac{\partial{L}}{\partial{Y_p}}f_a'(Z^o)\right]_{[1,4]}\left[H\right]_{[4,2]}^T$
#
# Para a camada escondida podemos escrever
#
# $\frac{\partial{L}}{\partial{W_{11}^h}}=\underbrace{\frac{\partial{L}}{\partial{Y_p}}f_a'(Z^o)\frac{\partial{Z^o}}{\partial{h_1}}\frac{\partial{h_1}}{\partial{Z_1^h}}}_{\frac{\partial{L}}{\partial{Z^h}}}\frac{\partial{Z_1^h}}{\partial{W_{11}^h}}=\underbrace{\frac{\partial{L}}{\partial{Y_p}}f_a'(Z^o)W_{11}^o f_a'(Z_1^h)}_{\frac{\partial{L}}{\partial{Z^h}}}X_1$
#
#
# $\frac{\partial{L}}{\partial{W_{12}^h}}=\frac{\partial{L}}{\partial{Y_p}}f_a'(Z^o)W_{11}^o f_a'(Z_1^h)X_2$
#
#
# $\frac{\partial{L}}{\partial{W_{21}^h}}=\frac{\partial{L}}{\partial{Y_p}}f_a'(Z^o)W_{12}^o f_a'(Z_2^h)X_1$
#
# $\frac{\partial{L}}{\partial{W_{22}^h}}=\frac{\partial{L}}{\partial{Y_p}}f_a'(Z^o)W_{12}^o f_a'(Z_2^h)X_2$
#
# $\left[\frac{\partial{L}}{\partial{Z^h}}\right ]_{[2,4]}=\begin{bmatrix} W_{11}^o \\ W_{12}^o\end{bmatrix}_{[2,1]}\begin{bmatrix} \frac{\partial{L}}{\partial{Z_1^o}} & \frac{\partial{L}}{\partial{Z_2^o}}&\frac{\partial{L}}{\partial{Z_3^o}}&\frac{\partial{L}}{\partial{Z_4^o}}\end{bmatrix}_{[1,4]}*\left[ f_a'(Z^h)\right]_{[4,2]}^T$
#
# e finalmente,
#
# $\left[ \frac{\partial{L}}{\partial{W^h}} \right]_{[2,2]}=\left[\frac{\partial{L}}{\partial{Z^h}}\right ]_{[2,4]}\begin{bmatrix} X_1^1&X_2^1\\ X_1^2&X_2^2\\ X_1^3&X_2^3\\ X_1^4&X_2^4\end{bmatrix}_{[4,2]}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class NeuralNetwork:
    
    """ Os dados de entrada devem ter o formato de matrizes x[n_input,n_amostras]
    e y[n_output,n_amostras]"""
    
    def __init__(self,hidden_activation, output_activation,loss,
                 n_input, n_hidden, n_output):
        # Armazena o número de neurônios em cada camada
        self.n_input = n_input
        self.n_hidden = n_hidden
        self.n_output = n_output
        
        # Armazena as funções de ativação para cada camada e a função custo
        self.hidden_activation = hidden_activation
        self.output_activation = output_activation
        self.loss=loss
        
        # Inicializa as matrizes de pesos
        np.random.seed(42)
        self.w_h=np.random.randn(n_hidden, n_input) * 0.01
        self.w_o=np.random.randn(n_output, n_hidden) * 0.01
        self.bias_h=np.zeros((n_hidden, 1))
        self.bias_o=np.zeros((n_output, 1))
        
        # Evolução da função custo
        self.loss_history=[]
   
    def activation_function(self,f_activ,x):
        if f_activ=='linear':
            return 1.*x
        if f_activ=='sigmoid':
            return 1 / (1 + np.exp(-x))        
        if f_activ == 'tanh':
            return np.tanh(x)
        if f_activ == 'relu':
            return np.maximum(0,x)         
    
    def deriv_activ_function(self,f_activ,x):
        if f_activ=='linear':
            return 1.
        if f_activ=='sigmoid':
            fx = self.activation_function(f_activ,x)
            return fx * (1 - fx)
        if f_activ == 'tanh':
            fx = self.activation_function(f_activ,x)
            return 1-fx**2
        if f_activ == 'relu':
            return (x>0).astype(np.float64)
    
    def compute_loss(self,y, y_p):

        if self.loss=='logloss':
            #Atenção: Se houver um termo nulo em y_p o cálculo resultará inf.
            eps=1e-15
            y_p=np.clip(y_p,eps,1-eps)
            cost = -(y * np.log(y_p) + (1 - y) * np.log(1 - y_p)).mean()
        if self.loss=='mse':
            cost=((y-y_p)**2).mean()
        return np.squeeze(cost)
    
    def deriv_loss(self,y,y_p):
        m=len(y[0,:])
        if self.loss=='logloss':
            #Atenção: Se houver um termo nulo ou 1 em y_p o cálculo resultará inf.
            eps=1e-15
            y_p=np.clip(y_p,eps,1-eps)
            return (y_p-y)/(y_p*(1-y_p))/m
        if self.loss=='mse':
            return -2*(y-y_p)/m 
    
    def forward_propagation(self,x):
        
        z_h = np.dot(self.w_h, x) + self.bias_h
        output_h = self.activation_function(self.hidden_activation,z_h)
        z_o = np.dot(self.w_o, output_h) + self.bias_o
        y_p = self.activation_function(self.output_activation,z_o)
        
        return z_h,z_o,output_h,y_p
    
    def backward_propagation(self,x, y,z_h, z_o, output_h, y_p):
        
        # Camada de saída
        # ================
        #d_L/d_y_p
        d_y_p=self.deriv_loss(y,y_p)
        #d_L/d_z_o
        dz_o =d_y_p*self.deriv_activ_function(self.output_activation,z_o)
        #d_L/d_w_o
        dw_o = np.dot(dz_o, output_h.T)
        #d_L/d_bias_o
        db_o = np.sum(dz_o, axis=1, keepdims=True)
        
        # Camada interna (hidden)
        # =======================       
        #d_L/d_z_h
        dz_h = np.dot(self.w_o.T, dz_o) * self.deriv_activ_function(self.hidden_activation,z_h)
        #d_L/d_w_h
        dw_h = np.dot(dz_h, x.T)
        #d_L/d_bias_h
        db_h = np.sum(dz_h, axis=1, keepdims=True)
        
        return dw_h,dw_o,db_h,db_o
    
    def train(self,x, y, epochs=1000, learning_rate=0.1):
        
        for i in range(epochs):
            
            # Forward propagation e Custo.
            z_h,z_o,output_h,y_p = self.forward_propagation(x)
            cost = self.compute_loss(y, y_p)
            
            # Recupera o vetor gradiente=[dw_o,db_o,dw_h,db_h]
            dw_h,dw_o,db_h,db_o = self.backward_propagation(x, y,z_h,z_o, output_h, y_p)
            
            # Atualiza os parâmetros com os gradientes computados (DG)           
            self.w_h-=learning_rate*dw_h        
            self.w_o-=learning_rate*dw_o
            self.bias_h-=learning_rate*db_h
            self.bias_o-=learning_rate*db_o
            
            if i % 10 == 0:
                print(f"Epoch {i}: Cost = {cost}")
                self.loss_history.append(cost)        
    
    def predict(self,x):
        _,_,_,y_p= self.forward_propagation(x)
        return y_p

# %%
from sklearn.preprocessing import StandardScaler
def plot_decision_boundaries(model, X, y, title="Fronteiras de Decisão da Rede Neural"):
    """
    Plota os dados e as fronteiras de decisão criadas pelo modelo.
    
    Parâmetros:
    - model: rede neural treinada
    - X: dados de entrada
    - y: rótulos (classes) dos dados
    - title: título do gráfico
    """
    # Define os limites do gráfico com base nos dados
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    
    # Cria uma grade para visualizar as fronteiras de decisão
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                         np.arange(y_min, y_max, 0.1))
    
    # Achata a grade em 2 arrays e concatena as colunas convertendo 
    # em um array onde cada item são as coordenadas 2D dos pontos.
    grid_points = np.c_[xx.ravel(), yy.ravel()]
    
    # Aplicaro modelo para cada ponto na grade
    Z = np.zeros(grid_points.shape[0])
    for i, point in enumerate(grid_points):       
        Z[i] = model.predict(point.reshape(2,1)).item()
    
    # Reformata Z para o formato 2D da grade
    Z = Z.reshape(xx.shape)
    
    # Plota as fronteiras de decisão e os pontos
    plt.figure(figsize=(6,6))
    levels=[-0.5,0.49,0.51,1.9]
    plt.contourf(xx, yy, Z,levels,alpha=0.3, cmap=plt.cm.RdBu)
    plt.contour(xx, yy, Z,levels,linewidths=1, colors='black')  
    
    # Plota os pontos de dados
    colors = ['red', 'blue']
    for i in np.unique(y):
        plt.scatter(X[y==i, 0], X[y==i, 1], 
                    label=f"Classe {i}", 
                    color=colors[int(i)], 
                    edgecolor='white', 
                    s=50)
    
    plt.title(title)
    plt.xlabel('Característica 1 (X)')
    plt.ylabel('Característica 2 (Y)')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Problema não linearmente separável

# %%
np.random.seed(0)
epochs=1000
n = 1550
Xt1 = np.random.uniform(low=[0, 0], high=[4, 4], size=(n,2))
drop = (Xt1[:, 0] < 3) & (Xt1[:, 1] < 3)# pontos x<3 e y < 3
Xt1 = Xt1[~drop]
yt1= np.ones(len(Xt1))# elimina os pontos selecionados

Xt2 = np.random.uniform(low=[0, 0], high=[4, 4], size=(n,2))
drop = (Xt2[:, 0] > 2.3) | (Xt2[:, 1] > 2.3)

Xt2 = Xt2[~drop]
yt2= np.zeros(len(Xt2))

X4 = np.concatenate([Xt1, Xt2])
y4 = np.concatenate([yt1, yt2])

scaler = StandardScaler()
X4 = scaler.fit_transform(X4)
m=len(X4[:,0])
x=X4.T
y=y4.reshape(1,m)
 

epochs=3000
learning_rate=0.2
n_input=x.shape[0]
n_hidden=16
n_output=1
hidden_activation='relu'
output_activation='sigmoid'
loss='logloss'

model= NeuralNetwork(hidden_activation, output_activation,loss, n_input, n_hidden, n_output)
model.train(x, y,epochs, learning_rate)
    
plot_decision_boundaries(model, X4, y4, 
    f"Rede Neural com {hidden_activation} (hidden) e {output_activation} (output)")   

plt.figure()    
epoch=np.arange(epochs/10)*10
loss_h=model.loss_history
plt.title('Loss vs. Epochs')
plt.plot(epoch,loss_h)
plt.xlabel('Epochs')
plt.grid()
plt.ylabel('Loss')  
plt.show()
# Out:
# Epoch 0: Cost = 0.693164264967852
# Epoch 10: Cost = 0.6872042351040248
# Epoch 20: Cost = 0.6842186561520782
# Epoch 30: Cost = 0.6805383738325805
# Epoch 40: Cost = 0.6714037449923289
# Epoch 50: Cost = 0.6458872478369693
# Epoch 60: Cost = 0.5835023524563008
# Epoch 70: Cost = 0.4759320262875497
# Epoch 80: Cost = 0.360173668209936
# Epoch 90: Cost = 0.27387921391047204
# Epoch 100: Cost = 0.22086695738006898
# Epoch 110: Cost = 0.18957973287882662
# Epoch 120: Cost = 0.1703932257796278
# Epoch 130: Cost = 0.15794906762240765
# Epoch 140: Cost = 0.14945084971450878
# Epoch 150: Cost = 0.14339586151609746
# Epoch 160: Cost = 0.138930236776436
# Epoch 170: Cost = 0.13554184297740443
# Epoch 180: Cost = 0.13291371090612292
# Epoch 190: Cost = 0.13083621497314302
# Epoch 200: Cost = 0.12916555141708436
# Epoch 210: Cost = 0.12780310124654926
# Epoch 220: Cost = 0.12667649415700705
# Epoch 230: Cost = 0.12573336145147554
# Epoch 240: Cost = 0.1249338923143408
# Epoch 250: Cost = 0.12424894280039375
# Epoch 260: Cost = 0.12365506322993387
# Epoch 270: Cost = 0.12313400990139435
# Epoch 280: Cost = 0.12267072755781301
# Epoch 290: Cost = 0.12225278504215578
# Epoch 300: Cost = 0.12187034372604294
# Epoch 310: Cost = 0.12151468424065524
# Epoch 320: Cost = 0.1211796035653545
# Epoch 330: Cost = 0.12085839837335474
# Epoch 340: Cost = 0.12054548710483268
# Epoch 350: Cost = 0.120235635115743
# Epoch 360: Cost = 0.11992403114385129
# Epoch 370: Cost = 0.11960721545184465
# Epoch 380: Cost = 0.11928029405693974
# Epoch 390: Cost = 0.11893925643853236
# Epoch 400: Cost = 0.11858010292043517
# Epoch 410: Cost = 0.11819887712872719
# Epoch 420: Cost = 0.1177928627674459
# Epoch 430: Cost = 0.11735913880070202
# Epoch 440: Cost = 0.11689277020005456
# Epoch 450: Cost = 0.11638958142538015
# Epoch 460: Cost = 0.1158449847797192
# Epoch 470: Cost = 0.11525472685163843
# Epoch 480: Cost = 0.11461462361206359
# Epoch 490: Cost = 0.11392017685642329
# Epoch 500: Cost = 0.11316672490867172
# Epoch 510: Cost = 0.11234976158003006
# Epoch 520: Cost = 0.11146487392239815
# Epoch 530: Cost = 0.11050771741836458
# Epoch 540: Cost = 0.10947379608154956
# Epoch 550: Cost = 0.10835913733522065
# Epoch 560: Cost = 0.10716056427624185
# Epoch 570: Cost = 0.10587463104861085
# Epoch 580: Cost = 0.10449863926940117
# Epoch 590: Cost = 0.10303031075554633
# Epoch 600: Cost = 0.10146905663127004
# Epoch 610: Cost = 0.0998150984894846
# Epoch 620: Cost = 0.09807016794185448
# Epoch 630: Cost = 0.09623541936279248
# Epoch 640: Cost = 0.09431310463298315
# Epoch 650: Cost = 0.09230635108643133
# Epoch 660: Cost = 0.09021585855359643
# Epoch 670: Cost = 0.08804088095470954
# Epoch 680: Cost = 0.08579064470884835
# Epoch 690: Cost = 0.08346957343933616
# Epoch 700: Cost = 0.08109611394166669
# Epoch 710: Cost = 0.0786884840079733
# Epoch 720: Cost = 0.07626170880623119
# Epoch 730: Cost = 0.07382947834144978
# Epoch 740: Cost = 0.07139895638015407
# Epoch 750: Cost = 0.06898212818240679
# Epoch 760: Cost = 0.06658728918336512
# Epoch 770: Cost = 0.06422201358697913
# Epoch 780: Cost = 0.061894914735085044
# Epoch 790: Cost = 0.059605632802734156
# Epoch 800: Cost = 0.057368105463723146
# Epoch 810: Cost = 0.055165898551832654
# Epoch 820: Cost = 0.05300531211668341
# Epoch 830: Cost = 0.050918225428943864
# Epoch 840: Cost = 0.048895123836324585
# Epoch 850: Cost = 0.04691838900870857
# Epoch 860: Cost = 0.045020100955217496
# Epoch 870: Cost = 0.043192746127609566
# Epoch 880: Cost = 0.041425841062131215
# Epoch 890: Cost = 0.03970844880853959
# Epoch 900: Cost = 0.038049214062065476
# Epoch 910: Cost = 0.036460061610364275
# Epoch 920: Cost = 0.03492185443876374
# Epoch 930: Cost = 0.03343613060932306
# Epoch 940: Cost = 0.03203270825989932
# Epoch 950: Cost = 0.030678919592554667
# Epoch 960: Cost = 0.02940633340437597
# Epoch 970: Cost = 0.02819073888190037
# Epoch 980: Cost = 0.027000244652759117
# Epoch 990: Cost = 0.025886989145043508
# Epoch 1000: Cost = 0.024840019748406793
# Epoch 1010: Cost = 0.023853490085857597
# Epoch 1020: Cost = 0.02291487998355424
# Epoch 1030: Cost = 0.022034064020831974
# Epoch 1040: Cost = 0.021206116697998486
# Epoch 1050: Cost = 0.020434081115949652
# Epoch 1060: Cost = 0.019712452210250753
# Epoch 1070: Cost = 0.01903576824312264
# Epoch 1080: Cost = 0.018387766114799628
# Epoch 1090: Cost = 0.017774940654392002
# Epoch 1100: Cost = 0.017199630529695115
# Epoch 1110: Cost = 0.016654073037993784
# Epoch 1120: Cost = 0.016139263864047206
# Epoch 1130: Cost = 0.01565505417166847
# Epoch 1140: Cost = 0.015197612270321048
# Epoch 1150: Cost = 0.014759392727438876
# Epoch 1160: Cost = 0.01433906190011568
# Epoch 1170: Cost = 0.013940528343663942
# Epoch 1180: Cost = 0.013560312156756947
# Epoch 1190: Cost = 0.01319732762207962
# Epoch 1200: Cost = 0.01285108610091794
# Epoch 1210: Cost = 0.012520197214294291
# Epoch 1220: Cost = 0.012204390405257504
# Epoch 1230: Cost = 0.011900846082002188
# Epoch 1240: Cost = 0.011611244541177602
# Epoch 1250: Cost = 0.011334365188523406
# Epoch 1260: Cost = 0.011068497365873953
# Epoch 1270: Cost = 0.010812332454365933
# Epoch 1280: Cost = 0.010566647281979702
# Epoch 1290: Cost = 0.010330737136977842
# Epoch 1300: Cost = 0.01010415039806204
# Epoch 1310: Cost = 0.009887056092058763
# Epoch 1320: Cost = 0.009678637418466576
# Epoch 1330: Cost = 0.0094781302291997
# Epoch 1340: Cost = 0.009285730510765276
# Epoch 1350: Cost = 0.00910012997645313
# Epoch 1360: Cost = 0.008920591086421865
# Epoch 1370: Cost = 0.008747379577419733
# Epoch 1380: Cost = 0.008580176523556596
# Epoch 1390: Cost = 0.00841866291835918
# Epoch 1400: Cost = 0.00826257106804039
# Epoch 1410: Cost = 0.008111728422407607
# Epoch 1420: Cost = 0.007965783448789517
# Epoch 1430: Cost = 0.007824395017375455
# Epoch 1440: Cost = 0.007687481059282587
# Epoch 1450: Cost = 0.007554726901999413
# Epoch 1460: Cost = 0.007425831399638273
# Epoch 1470: Cost = 0.007300908351103288
# Epoch 1480: Cost = 0.007179719856036556
# Epoch 1490: Cost = 0.007061955942876084
# Epoch 1500: Cost = 0.006947579192265005
# Epoch 1510: Cost = 0.006836521404643102
# Epoch 1520: Cost = 0.006728830120969744
# Epoch 1530: Cost = 0.006624182710856678
# Epoch 1540: Cost = 0.006522484262929264
# Epoch 1550: Cost = 0.006423493159548744
# Epoch 1560: Cost = 0.006327065950177149
# Epoch 1570: Cost = 0.006233011277858511
# Epoch 1580: Cost = 0.006141273004662809
# Epoch 1590: Cost = 0.0060512257238085
# Epoch 1600: Cost = 0.005963462832171756
# Epoch 1610: Cost = 0.005877885624973482
# Epoch 1620: Cost = 0.005794378157363036
# Epoch 1630: Cost = 0.005713008448720283
# Epoch 1640: Cost = 0.0056338961327142495
# Epoch 1650: Cost = 0.005556763405828763
# Epoch 1660: Cost = 0.005481818979120972
# Epoch 1670: Cost = 0.005408603222674445
# Epoch 1680: Cost = 0.0053371473649110115
# Epoch 1690: Cost = 0.005267371544032842
# Epoch 1700: Cost = 0.005199234792807472
# Epoch 1710: Cost = 0.005132681810589961
# Epoch 1720: Cost = 0.005067664309173627
# Epoch 1730: Cost = 0.005004130438167455
# Epoch 1740: Cost = 0.004941989545956772
# Epoch 1750: Cost = 0.004881236423754703
# Epoch 1760: Cost = 0.004821837364017449
# Epoch 1770: Cost = 0.004763734577169423
# Epoch 1780: Cost = 0.004706900482574054
# Epoch 1790: Cost = 0.004651288622969626
# Epoch 1800: Cost = 0.004596870399438563
# Epoch 1810: Cost = 0.004543598789805594
# Epoch 1820: Cost = 0.00449140080568718
# Epoch 1830: Cost = 0.0044402799988345265
# Epoch 1840: Cost = 0.004390202942924212
# Epoch 1850: Cost = 0.004341145681434865
# Epoch 1860: Cost = 0.004293080663979072
# Epoch 1870: Cost = 0.004245981555352522
# Epoch 1880: Cost = 0.004199819895457091
# Epoch 1890: Cost = 0.004154567993091406
# Epoch 1900: Cost = 0.004110195738825564
# Epoch 1910: Cost = 0.004066757866063746
# Epoch 1920: Cost = 0.004024197594523264
# Epoch 1930: Cost = 0.003982423319804177
# Epoch 1940: Cost = 0.003941385530418458
# Epoch 1950: Cost = 0.0039010905209558174
# Epoch 1960: Cost = 0.0038615418725622516
# Epoch 1970: Cost = 0.0038227224315374726
# Epoch 1980: Cost = 0.003784615700262879
# Epoch 1990: Cost = 0.0037471976032262162
# Epoch 2000: Cost = 0.0037104504321856494
# Epoch 2010: Cost = 0.0036743569672894752
# Epoch 2020: Cost = 0.0036389012255642755
# Epoch 2030: Cost = 0.0036040687080915105
# Epoch 2040: Cost = 0.003569841745375471
# Epoch 2050: Cost = 0.0035362050929921233
# Epoch 2060: Cost = 0.003503144184472868
# Epoch 2070: Cost = 0.003470645488363428
# Epoch 2080: Cost = 0.0034387008157684405
# Epoch 2090: Cost = 0.0034072895014794773
# Epoch 2100: Cost = 0.0033764004702707693
# Epoch 2110: Cost = 0.003346022056071047
# Epoch 2120: Cost = 0.00331615773783791
# Epoch 2130: Cost = 0.0032867765527113918
# Epoch 2140: Cost = 0.003257755626392179
# Epoch 2150: Cost = 0.0032291902399484407
# Epoch 2160: Cost = 0.003201080872843383
# Epoch 2170: Cost = 0.00317341581879032
# Epoch 2180: Cost = 0.003146185356050536
# Epoch 2190: Cost = 0.003119380562933005
# Epoch 2200: Cost = 0.003092991590558032
# Epoch 2210: Cost = 0.0030670095198307963
# Epoch 2220: Cost = 0.003041425891639546
# Epoch 2230: Cost = 0.0030162313769148976
# Epoch 2240: Cost = 0.0029914170621585475
# Epoch 2250: Cost = 0.0029669735863554814
# Epoch 2260: Cost = 0.0029428933581023982
# Epoch 2270: Cost = 0.0029191659758919593
# Epoch 2280: Cost = 0.0028957883357307447
# Epoch 2290: Cost = 0.0028727529395034777
# Epoch 2300: Cost = 0.00285005274632027
# Epoch 2310: Cost = 0.0028276807885695768
# Epoch 2320: Cost = 0.0028056296039889205
# Epoch 2330: Cost = 0.0027838925885764125
# Epoch 2340: Cost = 0.002762463761614434
# Epoch 2350: Cost = 0.0027413367532111276
# Epoch 2360: Cost = 0.0027204990895223417
# Epoch 2370: Cost = 0.0026999431517643955
# Epoch 2380: Cost = 0.002679669599384559
# Epoch 2390: Cost = 0.002659676416112361
# Epoch 2400: Cost = 0.002639956190051874
# Epoch 2410: Cost = 0.0026205033454329376
# Epoch 2420: Cost = 0.0026013131173377863
# Epoch 2430: Cost = 0.0025823808548207728
# Epoch 2440: Cost = 0.0025637003900543564
# Epoch 2450: Cost = 0.002545261314629321
# Epoch 2460: Cost = 0.0025270639727513157
# Epoch 2470: Cost = 0.0025091036967370096
# Epoch 2480: Cost = 0.0024913774832783886
# Epoch 2490: Cost = 0.0024738824626372663
# Epoch 2500: Cost = 0.0024566125518986903
# Epoch 2510: Cost = 0.0024395634808042138
# Epoch 2520: Cost = 0.002422732071155734
# Epoch 2530: Cost = 0.0024061133356075054
# Epoch 2540: Cost = 0.002389711989147448
# Epoch 2550: Cost = 0.0023734877314115885
# Epoch 2560: Cost = 0.0023574632829754796
# Epoch 2570: Cost = 0.002341637270727865
# Epoch 2580: Cost = 0.0023260059611456834
# Epoch 2590: Cost = 0.002310561443754395
# Epoch 2600: Cost = 0.0022952864236246663
# Epoch 2610: Cost = 0.0022801712425485304
# Epoch 2620: Cost = 0.0022652155511530677
# Epoch 2630: Cost = 0.002250433310549685
# Epoch 2640: Cost = 0.0022358279295297914
# Epoch 2650: Cost = 0.0022214061183897633
# Epoch 2660: Cost = 0.002207161460825985
# Epoch 2670: Cost = 0.002193084428692883
# Epoch 2680: Cost = 0.002179172053649248
# Epoch 2690: Cost = 0.002165419480083098
# Epoch 2700: Cost = 0.0021518228987903146
# Epoch 2710: Cost = 0.0021383772433008724
# Epoch 2720: Cost = 0.0021250845999999813
# Epoch 2730: Cost = 0.002111944014916233
# Epoch 2740: Cost = 0.0020989516567509483
# Epoch 2750: Cost = 0.0020861065165614667
# Epoch 2760: Cost = 0.002073405175616435
# Epoch 2770: Cost = 0.0020608462389142446
# Epoch 2780: Cost = 0.0020484259761608544
# Epoch 2790: Cost = 0.0020361439802742327
# Epoch 2800: Cost = 0.002023996195788014
# Epoch 2810: Cost = 0.002011982473534422
# Epoch 2820: Cost = 0.002000098996322597
# Epoch 2830: Cost = 0.001988344620179372
# Epoch 2840: Cost = 0.001976717492723191
# Epoch 2850: Cost = 0.0019652145360168328
# Epoch 2860: Cost = 0.001953834747928699
# Epoch 2870: Cost = 0.0019425756593136811
# Epoch 2880: Cost = 0.001931435114496404
# Epoch 2890: Cost = 0.0019204076475172506
# Epoch 2900: Cost = 0.0019094907279410761
# Epoch 2910: Cost = 0.001898687775347468
# Epoch 2920: Cost = 0.001887997985981324
# Epoch 2930: Cost = 0.0018774186536480613
# Epoch 2940: Cost = 0.0018669487754061158
# Epoch 2950: Cost = 0.0018565867092848716
# Epoch 2960: Cost = 0.0018463303519364916
# Epoch 2970: Cost = 0.0018361781362985902
# Epoch 2980: Cost = 0.001826128424204007
# Epoch 2990: Cost = 0.001816178817548926

# %% [markdown]
# ## Regressão Linear

# %%
np.random.seed(40)
x=np.linspace(-0.5,0.5,200).reshape(1,200)
y = 4 + 3 * x + 0.5*np.random.randn(200)/5

n_input=x.shape[0]
n_hidden=14
n_output=1
hidden_activation='relu'
output_activation='linear'
loss='mse'
epochs=1000
    
model=NeuralNetwork(hidden_activation,output_activation,loss,n_input,n_hidden,n_output)   
model.train(x,y,epochs,learning_rate=0.41)


X=np.zeros((1,1000))
X[0,:]=np.linspace(-0.75,0.75,1000)
y_p=model.predict(X)
xp=X[0,:]
yp=y_p[0,:]

plt.figure()
title='Aproximação por regressão linear'
plt.scatter(x,y,color='blue',label='dados de treino')
plt.plot(xp,yp,c='r', label='predição')
plt.legend()
plt.grid()
plt.title(title)
plt.show()

plt.figure()
epoch=np.arange(epochs/10)*10
loss_h=model.loss_history
plt.title('Loss vs. Epochs')
plt.plot(epoch,loss_h)
plt.xlabel('Epochs')
plt.grid()
plt.ylabel('Loss')
plt.show()
# Out:
# Epoch 0: Cost = 16.74197370429668
# Epoch 10: Cost = 0.7499187820029692
# Epoch 20: Cost = 0.44985121542179923
# Epoch 30: Cost = 0.06670417714849214
# Epoch 40: Cost = 0.26881662860533306
# Epoch 50: Cost = 0.028501999836591824
# Epoch 60: Cost = 0.6660245263982616
# Epoch 70: Cost = 0.20059901384466458
# Epoch 80: Cost = 0.17502026794318265
# Epoch 90: Cost = 0.18532147850873026
# Epoch 100: Cost = 0.15887653345824787
# Epoch 110: Cost = 0.13766066816000422
# Epoch 120: Cost = 0.11685008216819583
# Epoch 130: Cost = 0.09779626811532799
# Epoch 140: Cost = 0.08066379654210731
# Epoch 150: Cost = 0.06722901121134015
# Epoch 160: Cost = 0.055070526896459394
# Epoch 170: Cost = 0.044380556730326884
# Epoch 180: Cost = 0.03884667853705003
# Epoch 190: Cost = 0.03530946781116517
# Epoch 200: Cost = 0.032824487504235667
# Epoch 210: Cost = 0.028443820711679408
# Epoch 220: Cost = 0.0248688049981336
# Epoch 230: Cost = 0.021671074696124677
# Epoch 240: Cost = 0.019300807784970776
# Epoch 250: Cost = 0.017438619167201318
# Epoch 260: Cost = 0.016246986721517188
# Epoch 270: Cost = 0.01525583353240772
# Epoch 280: Cost = 0.014545225657553779
# Epoch 290: Cost = 0.013953033164291712
# Epoch 300: Cost = 0.01353846185462925
# Epoch 310: Cost = 0.01319104924425233
# Epoch 320: Cost = 0.012733551813504879
# Epoch 330: Cost = 0.012278203975123352
# Epoch 340: Cost = 0.011871084487805042
# Epoch 350: Cost = 0.011563705344796133
# Epoch 360: Cost = 0.011222177133383965
# Epoch 370: Cost = 0.01090933422555386
# Epoch 380: Cost = 0.01062436321641043
# Epoch 390: Cost = 0.010393208010732447
# Epoch 400: Cost = 0.010207178838743001
# Epoch 410: Cost = 0.010061787158833026
# Epoch 420: Cost = 0.009926550299141133
# Epoch 430: Cost = 0.00982271457990162
# Epoch 440: Cost = 0.009788352792780449
# Epoch 450: Cost = 0.00977354014558377
# Epoch 460: Cost = 0.009768604292897184
# Epoch 470: Cost = 0.009759641336540358
# Epoch 480: Cost = 0.009750843968220116
# Epoch 490: Cost = 0.00974275376398677
# Epoch 500: Cost = 0.009735837201469512
# Epoch 510: Cost = 0.009729772552623488
# Epoch 520: Cost = 0.009724478434910583
# Epoch 530: Cost = 0.009719866239120904
# Epoch 540: Cost = 0.009713421966307888
# Epoch 550: Cost = 0.009706780725317103
# Epoch 560: Cost = 0.00970074232563275
# Epoch 570: Cost = 0.009696836360632826
# Epoch 580: Cost = 0.009692953849238371
# Epoch 590: Cost = 0.009691339803968444
# Epoch 600: Cost = 0.009687898047549005
# Epoch 610: Cost = 0.009677556920138927
# Epoch 620: Cost = 0.00967006845190996
# Epoch 630: Cost = 0.009663523779711969
# Epoch 640: Cost = 0.009658841935967714
# Epoch 650: Cost = 0.009656919603715954
# Epoch 660: Cost = 0.009655466758537568
# Epoch 670: Cost = 0.009654243212817194
# Epoch 680: Cost = 0.009652562682860496
# Epoch 690: Cost = 0.009650936043873806
# Epoch 700: Cost = 0.009649439058700901
# Epoch 710: Cost = 0.009648058119276952
# Epoch 720: Cost = 0.009646782912027318
# Epoch 730: Cost = 0.009645604566901462
# Epoch 740: Cost = 0.009641453857398681
# Epoch 750: Cost = 0.009636430991675732
# Epoch 760: Cost = 0.009636644740444605
# Epoch 770: Cost = 0.009637896094961747
# Epoch 780: Cost = 0.009638420929174118
# Epoch 790: Cost = 0.009635094885799708
# Epoch 800: Cost = 0.009634481981428132
# Epoch 810: Cost = 0.00963341375484677
# Epoch 820: Cost = 0.00963284438773617
# Epoch 830: Cost = 0.009632505166514064
# Epoch 840: Cost = 0.009632286074957275
# Epoch 850: Cost = 0.009632136182431939
# Epoch 860: Cost = 0.009632029530509843
# Epoch 870: Cost = 0.009630852457355326
# Epoch 880: Cost = 0.009630767028070177
# Epoch 890: Cost = 0.009630316704721968
# Epoch 900: Cost = 0.009630211441731498
# Epoch 910: Cost = 0.009630136178643452
# Epoch 920: Cost = 0.009630085689704852
# Epoch 930: Cost = 0.009630047827645339
# Epoch 940: Cost = 0.00963001617833099
# Epoch 950: Cost = 0.00962998737440483
# Epoch 960: Cost = 0.009629959722501
# Epoch 970: Cost = 0.00962993241795389
# Epoch 980: Cost = 0.009629905117165024
# Epoch 990: Cost = 0.009629889558106633

# %% [markdown]
# ## Regressão Quadrática

# %%
# dados do problema
# =====================
np.random.seed(42)
num_points = 200
x = np.linspace(-0.5,0.5, num_points).reshape(1,num_points)
y = (x)**2 

n_input=x.shape[0]
n_hidden=15
n_output=1
hidden_activation='relu'
output_activation='linear'
loss='mse'
epochs=4000

    
model=NeuralNetwork(hidden_activation,output_activation,loss,n_input,n_hidden,n_output)   
model.train(x,y,epochs,learning_rate=0.4)

x_p=np.linspace(x.min()-0.2,x.max()+0.2,1000)
y_p=model.predict(x_p.reshape(1,1000)).squeeze()

# Distribuição dos pontos & representação linear
#===============================================
fig=plt.figure()
ax = fig.add_subplot(111)
title='Aproximação por regressão polinomial '
plt.scatter(x, y, facecolors='b', edgecolors='b', label='dados de treino')
plt.plot(x_p,y_p,c='r',label='predição')
plt.grid()
plt.legend()
plt.title(title)
plt.show()

fig=plt.figure()
epoch=np.arange(epochs/10)*10
loss_h=model.loss_history
plt.title('Loss vs. Epochs')
plt.plot(epoch,loss_h)
plt.xlabel('Epochs')
plt.grid()
plt.ylabel('Loss')
plt.show()
# Out:
# Epoch 0: Cost = 0.012767646981471783
# Epoch 10: Cost = 0.005669839788304927
# Epoch 20: Cost = 0.005668898040757378
# Epoch 30: Cost = 0.00566795325163702
# Epoch 40: Cost = 0.005667083391456135
# Epoch 50: Cost = 0.005666319802091413
# Epoch 60: Cost = 0.005665556846041586
# Epoch 70: Cost = 0.005664776722373497
# Epoch 80: Cost = 0.005663985206019153
# Epoch 90: Cost = 0.005663192830400017
# Epoch 100: Cost = 0.0056624057076457845
# Epoch 110: Cost = 0.005661619620734792
# Epoch 120: Cost = 0.005660817941160395
# Epoch 130: Cost = 0.005659982081553719
# Epoch 140: Cost = 0.005659098865100607
# Epoch 150: Cost = 0.005658158523322632
# Epoch 160: Cost = 0.005657153572146898
# Epoch 170: Cost = 0.005656076487327792
# Epoch 180: Cost = 0.005654919840747583
# Epoch 190: Cost = 0.005653675266418869
# Epoch 200: Cost = 0.005652333937368125
# Epoch 210: Cost = 0.005650886610863186
# Epoch 220: Cost = 0.005649323174004675
# Epoch 230: Cost = 0.005647632579091775
# Epoch 240: Cost = 0.005645803023939386
# Epoch 250: Cost = 0.005643821769206185
# Epoch 260: Cost = 0.005641675048777943
# Epoch 270: Cost = 0.005639347977788642
# Epoch 280: Cost = 0.0056368244510354186
# Epoch 290: Cost = 0.005634087076524841
# Epoch 300: Cost = 0.005631117033486611
# Epoch 310: Cost = 0.005627893930298305
# Epoch 320: Cost = 0.005624395794115422
# Epoch 330: Cost = 0.005620598848573208
# Epoch 340: Cost = 0.005616477272204043
# Epoch 350: Cost = 0.00561200341429172
# Epoch 360: Cost = 0.005607147188568969
# Epoch 370: Cost = 0.0056018762684531985
# Epoch 380: Cost = 0.005596155408409638
# Epoch 390: Cost = 0.005589947198686574
# Epoch 400: Cost = 0.005583210710414442
# Epoch 410: Cost = 0.0055759022517663645
# Epoch 420: Cost = 0.005567974836570877
# Epoch 430: Cost = 0.005559377398836055
# Epoch 440: Cost = 0.0055500559702546855
# Epoch 450: Cost = 0.0055399514723539385
# Epoch 460: Cost = 0.005529001992150364
# Epoch 470: Cost = 0.005517140139641252
# Epoch 480: Cost = 0.0055042939297921785
# Epoch 490: Cost = 0.005490386802260816
# Epoch 500: Cost = 0.00547533767523023
# Epoch 510: Cost = 0.005459059285044918
# Epoch 520: Cost = 0.005441459077642917
# Epoch 530: Cost = 0.005422439697625103
# Epoch 540: Cost = 0.005401897350767433
# Epoch 550: Cost = 0.0053797224485698635
# Epoch 560: Cost = 0.005355798647096999
# Epoch 570: Cost = 0.005330002515239739
# Epoch 580: Cost = 0.005302204033412154
# Epoch 590: Cost = 0.0052722667159152406
# Epoch 600: Cost = 0.005240047824540353
# Epoch 610: Cost = 0.005205416125356599
# Epoch 620: Cost = 0.00516822204935299
# Epoch 630: Cost = 0.005128319365478904
# Epoch 640: Cost = 0.005085548534713613
# Epoch 650: Cost = 0.0050397541831383305
# Epoch 660: Cost = 0.004990775883578962
# Epoch 670: Cost = 0.004938448405277944
# Epoch 680: Cost = 0.0048826050667774715
# Epoch 690: Cost = 0.004823082197343726
# Epoch 700: Cost = 0.004759728436686245
# Epoch 710: Cost = 0.004692439384601393
# Epoch 720: Cost = 0.004621066587220199
# Epoch 730: Cost = 0.004545500671099002
# Epoch 740: Cost = 0.004465664623701846
# Epoch 750: Cost = 0.004381469220583492
# Epoch 760: Cost = 0.004292856231471101
# Epoch 770: Cost = 0.004199802253224669
# Epoch 780: Cost = 0.0041023238444139664
# Epoch 790: Cost = 0.0040004795096731886
# Epoch 800: Cost = 0.0038943979672835527
# Epoch 810: Cost = 0.0037842369801995355
# Epoch 820: Cost = 0.003670186949062665
# Epoch 830: Cost = 0.003552502911147627
# Epoch 840: Cost = 0.0034314972999046687
# Epoch 850: Cost = 0.0033075363155122134
# Epoch 860: Cost = 0.0031810448864585646
# Epoch 870: Cost = 0.003052499771648646
# Epoch 880: Cost = 0.0029224271455515973
# Epoch 890: Cost = 0.002791391748360499
# Epoch 900: Cost = 0.0026599982178433456
# Epoch 910: Cost = 0.0025288663289013123
# Epoch 920: Cost = 0.002398629622414663
# Epoch 930: Cost = 0.002269904040006545
# Epoch 940: Cost = 0.002143299282983684
# Epoch 950: Cost = 0.0020194054671356853
# Epoch 960: Cost = 0.0018987829591423637
# Epoch 970: Cost = 0.0017819527839011287
# Epoch 980: Cost = 0.0016694333570666422
# Epoch 990: Cost = 0.0015616291920760887
# Epoch 1000: Cost = 0.001458834701699688
# Epoch 1010: Cost = 0.0013613132327092697
# Epoch 1020: Cost = 0.0012692630540473559
# Epoch 1030: Cost = 0.0011828148731061483
# Epoch 1040: Cost = 0.0011020543508601809
# Epoch 1050: Cost = 0.0010269593645244562
# Epoch 1060: Cost = 0.0009574303247024237
# Epoch 1070: Cost = 0.0008933375155046113
# Epoch 1080: Cost = 0.0008345063730444947
# Epoch 1090: Cost = 0.000780716232926418
# Epoch 1100: Cost = 0.0007316956174384045
# Epoch 1110: Cost = 0.0006871792951903474
# Epoch 1120: Cost = 0.0006468873228783946
# Epoch 1130: Cost = 0.000610441891864279
# Epoch 1140: Cost = 0.0005774863192299542
# Epoch 1150: Cost = 0.0005477767797221321
# Epoch 1160: Cost = 0.0005208861626650277
# Epoch 1170: Cost = 0.0004965737002852303
# Epoch 1180: Cost = 0.0004743390091952165
# Epoch 1190: Cost = 0.0004541550258871055
# Epoch 1200: Cost = 0.00043534819808013374
# Epoch 1210: Cost = 0.0004180143698669809
# Epoch 1220: Cost = 0.00040173421735607037
# Epoch 1230: Cost = 0.000386262258227381
# Epoch 1240: Cost = 0.00037164967488714085
# Epoch 1250: Cost = 0.00035756017949022887
# Epoch 1260: Cost = 0.0003440474468376598
# Epoch 1270: Cost = 0.00033102184881417745
# Epoch 1280: Cost = 0.00031848516746893084
# Epoch 1290: Cost = 0.0003063998720235785
# Epoch 1300: Cost = 0.00029488294570335845
# Epoch 1310: Cost = 0.00028386195778520797
# Epoch 1320: Cost = 0.00027324132509513
# Epoch 1330: Cost = 0.00026322807494306
# Epoch 1340: Cost = 0.0002537464391494759
# Epoch 1350: Cost = 0.0002446231579112061
# Epoch 1360: Cost = 0.00023615680386195214
# Epoch 1370: Cost = 0.0002279595743683882
# Epoch 1380: Cost = 0.000220350410641535
# Epoch 1390: Cost = 0.00021301508480839885
# Epoch 1400: Cost = 0.0002062032985855503
# Epoch 1410: Cost = 0.00019961092301270863
# Epoch 1420: Cost = 0.00019350157970752076
# Epoch 1430: Cost = 0.0001876104263919855
# Epoch 1440: Cost = 0.00018205847677820895
# Epoch 1450: Cost = 0.0001768257322808965
# Epoch 1460: Cost = 0.00017180815316511532
# Epoch 1470: Cost = 0.0001670839177165914
# Epoch 1480: Cost = 0.00016260040192468922
# Epoch 1490: Cost = 0.0001583358431855688
# Epoch 1500: Cost = 0.00015426563533337787
# Epoch 1510: Cost = 0.0001504348362642369
# Epoch 1520: Cost = 0.00014677272165170198
# Epoch 1530: Cost = 0.00014329624555581747
# Epoch 1540: Cost = 0.00013999215550379452
# Epoch 1550: Cost = 0.00013684000765354476
# Epoch 1560: Cost = 0.00013384399769990286
# Epoch 1570: Cost = 0.00013099277624582965
# Epoch 1580: Cost = 0.00012831222000309818
# Epoch 1590: Cost = 0.00012574690834532714
# Epoch 1600: Cost = 0.00012325020912870932
# Epoch 1610: Cost = 0.00012088799088463888
# Epoch 1620: Cost = 0.00011866364346625039
# Epoch 1630: Cost = 0.0001165801268428026
# Epoch 1640: Cost = 0.000114600265599504
# Epoch 1650: Cost = 0.00011263175867634496
# Epoch 1660: Cost = 0.00011072319009092564
# Epoch 1670: Cost = 0.00010894621288807808
# Epoch 1680: Cost = 0.00010727607831125384
# Epoch 1690: Cost = 0.00010570932725930333
# Epoch 1700: Cost = 0.00010421746892492963
# Epoch 1710: Cost = 0.00010272270644511426
# Epoch 1720: Cost = 0.00010128630170217586
# Epoch 1730: Cost = 9.991623174450963e-05
# Epoch 1740: Cost = 9.861159429883628e-05
# Epoch 1750: Cost = 9.733646944195092e-05
# Epoch 1760: Cost = 9.613880403916329e-05
# Epoch 1770: Cost = 9.500217542813524e-05
# Epoch 1780: Cost = 9.385896589929828e-05
# Epoch 1790: Cost = 9.272581297743864e-05
# Epoch 1800: Cost = 9.165615807624424e-05
# Epoch 1810: Cost = 9.061887147974887e-05
# Epoch 1820: Cost = 8.953440274781309e-05
# Epoch 1830: Cost = 8.851080727926154e-05
# Epoch 1840: Cost = 8.751863572610927e-05
# Epoch 1850: Cost = 8.649084728300554e-05
# Epoch 1860: Cost = 8.549359024863963e-05
# Epoch 1870: Cost = 8.445073027968836e-05
# Epoch 1880: Cost = 8.340145253001397e-05
# Epoch 1890: Cost = 8.239490045479018e-05
# Epoch 1900: Cost = 8.133170988528482e-05
# Epoch 1910: Cost = 8.029473029314912e-05
# Epoch 1920: Cost = 7.921732223831068e-05
# Epoch 1930: Cost = 7.81515651819023e-05
# Epoch 1940: Cost = 7.706972260147614e-05
# Epoch 1950: Cost = 7.595538161641821e-05
# Epoch 1960: Cost = 7.485780546501096e-05
# Epoch 1970: Cost = 7.373636233670109e-05
# Epoch 1980: Cost = 7.264067335728391e-05
# Epoch 1990: Cost = 7.151747014099945e-05
# Epoch 2000: Cost = 7.042147073926232e-05
# Epoch 2010: Cost = 6.928363053567045e-05
# Epoch 2020: Cost = 6.816517419030988e-05
# Epoch 2030: Cost = 6.707687635599203e-05
# Epoch 2040: Cost = 6.59768350215766e-05
# Epoch 2050: Cost = 6.490610592537733e-05
# Epoch 2060: Cost = 6.383187937153774e-05
# Epoch 2070: Cost = 6.275742470701747e-05
# Epoch 2080: Cost = 6.16961665057064e-05
# Epoch 2090: Cost = 6.062648298311017e-05
# Epoch 2100: Cost = 5.9604428864766576e-05
# Epoch 2110: Cost = 5.855117317326128e-05
# Epoch 2120: Cost = 5.7502275061296886e-05
# Epoch 2130: Cost = 5.646413851725087e-05
# Epoch 2140: Cost = 5.5447582631082214e-05
# Epoch 2150: Cost = 5.4390274367173836e-05
# Epoch 2160: Cost = 5.336965759054598e-05
# Epoch 2170: Cost = 5.238016705137285e-05
# Epoch 2180: Cost = 5.132550756988104e-05
# Epoch 2190: Cost = 5.0329956017627596e-05
# Epoch 2200: Cost = 4.9340076225115336e-05
# Epoch 2210: Cost = 4.8347540394187985e-05
# Epoch 2220: Cost = 4.739029446873361e-05
# Epoch 2230: Cost = 4.6449714009644814e-05
# Epoch 2240: Cost = 4.5538435917676e-05
# Epoch 2250: Cost = 4.4620983089448555e-05
# Epoch 2260: Cost = 4.374590555231552e-05
# Epoch 2270: Cost = 4.290977199612078e-05
# Epoch 2280: Cost = 4.2086421285457965e-05
# Epoch 2290: Cost = 4.12923543197372e-05
# Epoch 2300: Cost = 4.0514785840332306e-05
# Epoch 2310: Cost = 3.977432930743216e-05
# Epoch 2320: Cost = 3.9073769760096745e-05
# Epoch 2330: Cost = 3.8371784359156403e-05
# Epoch 2340: Cost = 3.769240580087583e-05
# Epoch 2350: Cost = 3.7049668961840875e-05
# Epoch 2360: Cost = 3.643429550606923e-05
# Epoch 2370: Cost = 3.583621501487988e-05
# Epoch 2380: Cost = 3.525576574236304e-05
# Epoch 2390: Cost = 3.469127746973175e-05
# Epoch 2400: Cost = 3.4135009258740385e-05
# Epoch 2410: Cost = 3.3601870174210254e-05
# Epoch 2420: Cost = 3.309032778014648e-05
# Epoch 2430: Cost = 3.259459742732072e-05
# Epoch 2440: Cost = 3.210879763680524e-05
# Epoch 2450: Cost = 3.1636765283878104e-05
# Epoch 2460: Cost = 3.11811765773004e-05
# Epoch 2470: Cost = 3.0740846493147754e-05
# Epoch 2480: Cost = 3.0314768869413285e-05
# Epoch 2490: Cost = 2.9896225941858508e-05
# Epoch 2500: Cost = 2.9489607568542347e-05
# Epoch 2510: Cost = 2.9094022136792385e-05
# Epoch 2520: Cost = 2.8703047079183104e-05
# Epoch 2530: Cost = 2.832166778439619e-05
# Epoch 2540: Cost = 2.7946389313938017e-05
# Epoch 2550: Cost = 2.7578146067349912e-05
# Epoch 2560: Cost = 2.722061070434941e-05
# Epoch 2570: Cost = 2.6871357583721565e-05
# Epoch 2580: Cost = 2.6532021039035622e-05
# Epoch 2590: Cost = 2.620211288282236e-05
# Epoch 2600: Cost = 2.588120337728805e-05
# Epoch 2610: Cost = 2.5566068051654537e-05
# Epoch 2620: Cost = 2.52582983947655e-05
# Epoch 2630: Cost = 2.4958338430892367e-05
# Epoch 2640: Cost = 2.4661923983452724e-05
# Epoch 2650: Cost = 2.4372399914491164e-05
# Epoch 2660: Cost = 2.408915204040649e-05
# Epoch 2670: Cost = 2.381237911221277e-05
# Epoch 2680: Cost = 2.3540668873093714e-05
# Epoch 2690: Cost = 2.327374636094114e-05
# Epoch 2700: Cost = 2.301288283078897e-05
# Epoch 2710: Cost = 2.2757431014551103e-05
# Epoch 2720: Cost = 2.2506174390131036e-05
# Epoch 2730: Cost = 2.2260886725679246e-05
# Epoch 2740: Cost = 2.2021352829740764e-05
# Epoch 2750: Cost = 2.17873881231068e-05
# Epoch 2760: Cost = 2.15557520470525e-05
# Epoch 2770: Cost = 2.132655734188825e-05
# Epoch 2780: Cost = 2.110172870405839e-05
# Epoch 2790: Cost = 2.088177477071999e-05
# Epoch 2800: Cost = 2.0666273850291237e-05
# Epoch 2810: Cost = 2.0455212554165844e-05
# Epoch 2820: Cost = 2.0248614151415186e-05
# Epoch 2830: Cost = 2.004633449666504e-05
# Epoch 2840: Cost = 1.984761526936844e-05
# Epoch 2850: Cost = 1.96530827257465e-05
# Epoch 2860: Cost = 1.9462356865078637e-05
# Epoch 2870: Cost = 1.9273932433978763e-05
# Epoch 2880: Cost = 1.9089940131276393e-05
# Epoch 2890: Cost = 1.8909708551995144e-05
# Epoch 2900: Cost = 1.87302157910276e-05
# Epoch 2910: Cost = 1.8552389204824227e-05
# Epoch 2920: Cost = 1.837807361519122e-05
# Epoch 2930: Cost = 1.820723918789472e-05
# Epoch 2940: Cost = 1.8039780146167243e-05
# Epoch 2950: Cost = 1.7875603734598648e-05
# Epoch 2960: Cost = 1.7714625166330088e-05
# Epoch 2970: Cost = 1.7555894814158537e-05
# Epoch 2980: Cost = 1.7398250815601014e-05
# Epoch 2990: Cost = 1.7242791071750076e-05
# Epoch 3000: Cost = 1.7090382455075223e-05
# Epoch 3010: Cost = 1.6940839912319894e-05
# Epoch 3020: Cost = 1.679414075804274e-05
# Epoch 3030: Cost = 1.6650901847474468e-05
# Epoch 3040: Cost = 1.6510393804711754e-05
# Epoch 3050: Cost = 1.6372553083647215e-05
# Epoch 3060: Cost = 1.6234222538157356e-05
# Epoch 3070: Cost = 1.609737160122125e-05
# Epoch 3080: Cost = 1.596309249484505e-05
# Epoch 3090: Cost = 1.5829905821181525e-05
# Epoch 3100: Cost = 1.569859527767845e-05
# Epoch 3110: Cost = 1.5569659542097273e-05
# Epoch 3120: Cost = 1.5443040918305654e-05
# Epoch 3130: Cost = 1.5318682690391385e-05
# Epoch 3140: Cost = 1.519642148530612e-05
# Epoch 3150: Cost = 1.5076332633530889e-05
# Epoch 3160: Cost = 1.495829860097722e-05
# Epoch 3170: Cost = 1.4842212226864598e-05
# Epoch 3180: Cost = 1.4728694820714252e-05
# Epoch 3190: Cost = 1.461730039991233e-05
# Epoch 3200: Cost = 1.4507867987368673e-05
# Epoch 3210: Cost = 1.4400357740080153e-05
# Epoch 3220: Cost = 1.4293495587163931e-05
# Epoch 3230: Cost = 1.4188011501254888e-05
# Epoch 3240: Cost = 1.4081211442127707e-05
# Epoch 3250: Cost = 1.3975167620618799e-05
# Epoch 3260: Cost = 1.3871038622757482e-05
# Epoch 3270: Cost = 1.3768680120407498e-05
# Epoch 3280: Cost = 1.3668084306229824e-05
# Epoch 3290: Cost = 1.3569203090510133e-05
# Epoch 3300: Cost = 1.347199583385738e-05
# Epoch 3310: Cost = 1.3376426057317807e-05
# Epoch 3320: Cost = 1.3282459920140642e-05
# Epoch 3330: Cost = 1.3190065447526714e-05
# Epoch 3340: Cost = 1.309942619097416e-05
# Epoch 3350: Cost = 1.3010606082792123e-05
# Epoch 3360: Cost = 1.2923255170510465e-05
# Epoch 3370: Cost = 1.2835873533817632e-05
# Epoch 3380: Cost = 1.2749859473540899e-05
# Epoch 3390: Cost = 1.2665264957348772e-05
# Epoch 3400: Cost = 1.2582061456243891e-05
# Epoch 3410: Cost = 1.2500228102150167e-05
# Epoch 3420: Cost = 1.2419732335589502e-05
# Epoch 3430: Cost = 1.2340549525562841e-05
# Epoch 3440: Cost = 1.2260845785705078e-05
# Epoch 3450: Cost = 1.2180081382206013e-05
# Epoch 3460: Cost = 1.2100789310950714e-05
# Epoch 3470: Cost = 1.2022855507144435e-05
# Epoch 3480: Cost = 1.1946215426868607e-05
# Epoch 3490: Cost = 1.1870824445373666e-05
# Epoch 3500: Cost = 1.1796647737563112e-05
# Epoch 3510: Cost = 1.1723655846811465e-05
# Epoch 3520: Cost = 1.1652149562529926e-05
# Epoch 3530: Cost = 1.1581443316616914e-05
# Epoch 3540: Cost = 1.1510930398353687e-05
# Epoch 3550: Cost = 1.1441531057417335e-05
# Epoch 3560: Cost = 1.1373279551164557e-05
# Epoch 3570: Cost = 1.1306099713934426e-05
# Epoch 3580: Cost = 1.1239966033842527e-05
# Epoch 3590: Cost = 1.1174859032310937e-05
# Epoch 3600: Cost = 1.1110759955418551e-05
# Epoch 3610: Cost = 1.1047650645201627e-05
# Epoch 3620: Cost = 1.0985513460351186e-05
# Epoch 3630: Cost = 1.0924331221706848e-05
# Epoch 3640: Cost = 1.0864087171848895e-05
# Epoch 3650: Cost = 1.080476494365476e-05
# Epoch 3660: Cost = 1.0746348535064252e-05
# Epoch 3670: Cost = 1.0688822288391395e-05
# Epoch 3680: Cost = 1.0629066066016072e-05
# Epoch 3690: Cost = 1.056943636993123e-05
# Epoch 3700: Cost = 1.0510879281930099e-05
# Epoch 3710: Cost = 1.045341796795841e-05
# Epoch 3720: Cost = 1.039713513118328e-05
# Epoch 3730: Cost = 1.0340629077715923e-05
# Epoch 3740: Cost = 1.0285003118152376e-05
# Epoch 3750: Cost = 1.0230225523931473e-05
# Epoch 3760: Cost = 1.0176273837693237e-05
# Epoch 3770: Cost = 1.0123129020511725e-05
# Epoch 3780: Cost = 1.0070773958177634e-05
# Epoch 3790: Cost = 1.0018602785085907e-05
# Epoch 3800: Cost = 9.962471226500829e-06
# Epoch 3810: Cost = 9.908373549733954e-06
# Epoch 3820: Cost = 9.855622594898838e-06
# Epoch 3830: Cost = 9.804017236628704e-06
# Epoch 3840: Cost = 9.75343018420016e-06
# Epoch 3850: Cost = 9.703773121194253e-06
# Epoch 3860: Cost = 9.654981425098751e-06
# Epoch 3870: Cost = 9.607005858192696e-06
# Epoch 3880: Cost = 9.5598076473295e-06
# Epoch 3890: Cost = 9.513355374872279e-06
# Epoch 3900: Cost = 9.467622919309504e-06
# Epoch 3910: Cost = 9.42258804548728e-06
# Epoch 3920: Cost = 9.378235373056866e-06
# Epoch 3930: Cost = 9.334637460942336e-06
# Epoch 3940: Cost = 9.291985526578614e-06
# Epoch 3950: Cost = 9.249958469789117e-06
# Epoch 3960: Cost = 9.208541148186404e-06
# Epoch 3970: Cost = 9.164392131701536e-06
# Epoch 3980: Cost = 9.119370070101378e-06
# Epoch 3990: Cost = 9.075221866575866e-06

# %% [markdown]
# ### preparação dos dados

# %% [markdown]
# ### Método dos Gradientes Descendentes

# %%
import numpy as np
import matplotlib.pyplot as plt

def cost_func(x):
    return x**2 - 4 * x + 1

def gradient(x):
    return 2*x - 4

def gradient_descent(gradient, start, learn_rate, max_iter, tol):
    x = start
    steps = [start] # records learning steps

    for _ in range(max_iter):
        diff = learn_rate * gradient(x)
        if np.abs(diff) < tol:
            break
        x = x - diff
        steps.append(x)

    return x, steps


x_values = np.linspace(-4, 11, 400)
y_values = cost_func(x_values)
initial_x = 9
iterations = 100
tolerance = 1e-6
learning_rates = [0.1, 0.3, 0.8, 0.9]


def gradient_descent_curve(ax, learning_rate):
    final_x, history = gradient_descent(gradient, initial_x, learning_rate, iterations, tolerance)

    ax.plot(x_values, y_values, label=f'Cost function: $J(x) = x^2 - 4x + 1$', lw=1, color='black')

    ax.scatter(history, [cost_func(x) for x in history], color='pink', zorder=5, label='Steps')
    ax.plot(history, [cost_func(x) for x in history], 'r--', lw=1, zorder=5)

    ax.annotate('Start', xy=(history[0], cost_func(history[0])), xytext=(history[0], cost_func(history[0]) + 10),
                arrowprops=dict(facecolor='black', shrink=0.05), ha='center')
    ax.annotate('End', xy=(final_x, cost_func(final_x)), xytext=(final_x, cost_func(final_x) + 10),
                arrowprops=dict(facecolor='black', shrink=0.05), ha='center')
    
    ax.set_title(f'Learning Rate: {learning_rate}')
    ax.set_xlabel('Input feature: x')
    ax.set_ylabel('Cost: J')
    ax.grid(True, alpha=0.5, ls='--', color='grey')
    ax.legend()

fig, axs = plt.subplots(1, 4, figsize=(20, 5))
fig.suptitle('Gradient Descent Steps by Learning Rate')

for ax, lr in zip(axs.flatten(), learning_rates):
    gradient_descent_curve(ax=ax, learning_rate=lr)

# %% [markdown]
# ### Método dos Gradientes Conjugados Estocástico (SGD)

# %% [markdown]
# Considere o problema de minimização da função de perda/custo abaixo:
#
# $$ \vec{w}=\vec{w}-\eta\vec{\nabla_w}(\vec{w})$$
# onde, para um problema de regressão linear,
# $$\vec{y}(\vec{w})=\vec{b_0}+\vec{w}.\vec{x}.$$
#
# Então,
#
# $$J=\sum_i\frac{1}{m}(\vec{y_pî}(\vec{w})-\vec{y^i})^2\rightarrow \frac{dJ}{d\vec{w}}=\frac{2}{m}\sum_i(\vec{y_p^i}-\vec{y^i}).\frac{d\vec{y_p^i}}{d\vec{w}}=\frac{2}{m}\sum_i(\vec{y_p^i}-\vec{y^i}).\vec{x^i}$$
#
# No Método estocástico, o gradiente é calculado para cada amostra de treinamento (ou um pequeno subconjunto de amostras de treinamento) em vez de para todo o conjunto de dados.

# %%
import numpy as np

# geração de dados (pontos randômicos)
X = 2 * np.random.rand(100, 1)  
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
def sgd(X, y, learning_rate=0.1, epochs=1000, batch_size=1):
    m = len(X)  
    w = np.random.randn(2, 1) 
    
    
    # Adiciona as bias em X (X_0 = 1)
    X_bias = np.c_[np.ones((m, 1)), X]

    loss_history = []  

    for epoch in range(epochs):
        # embaralha os dados 
        indices = np.random.permutation(m)
        X_shuffled = X_bias[indices]
        y_shuffled = y[indices]

        for i in range(0, m, batch_size):
            # Seleciona um lote (bath) dos dados
            X_batch = X_shuffled[i:i+batch_size]
            y_batch = y_shuffled[i:i+batch_size]

            # calcula o gradiente
            gradients = 2 / batch_size * X_batch.T.dot(X_batch.dot(w) - y_batch)

            # atualiza w
            w -= learning_rate * gradients

        # Custo (Mean Squared Error)
        predictions = X_bias.dot(w)
        loss = np.mean((predictions - y) ** 2)
        loss_history.append(loss)

        # Print progress every 100 epochs
        if epoch % 100 == 0:
            print(f"Epoch {epoch}, Loss: {loss}")

    return w, loss_history

# %%
# SGD
w_final, loss_history = sgd(X, y, learning_rate=0.005, epochs=1000, batch_size=1)
# Out:
# Epoch 0, Loss: 2.00945204165903
# Epoch 100, Loss: 0.8761184757527184
# Epoch 200, Loss: 0.8776268749431924
# Epoch 300, Loss: 0.8760545529480664
# Epoch 400, Loss: 0.8888732307782762
# Epoch 500, Loss: 0.8761601409154998
# Epoch 600, Loss: 0.8761479537176746
# Epoch 700, Loss: 0.8782779141901129
# Epoch 800, Loss: 0.8767338293180558
# Epoch 900, Loss: 0.8808958227053477

# %%
import matplotlib.pyplot as plt

# Plot the cost history
plt.plot(loss_history)
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.title('Loss Function during Training')
plt.show()

# %%
# Plot the data and the regression line
fig=plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
w_0 = np.random.randn(2, 1)
plt.scatter(X, y, color='blue', label='Pontos de dados')
plt.plot(X, np.c_[np.ones((X.shape[0], 1)), X].dot(w_0), color='red', label=' linha sem ajuste de dados')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linha de ajuste não treinada')
plt.legend()
plt.subplot(1,2,2)
plt.scatter(X, y, color='blue', label='Pontos de dados')
plt.plot(X, np.c_[np.ones((X.shape[0], 1)), X].dot(w_final), color='red', label='SGD linha de ajuste de dados')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Regressão Linear com o Método dos Gradientes Conjugados Estocástico')
plt.legend()
plt.show()

# %% [markdown]
# # Problemas de Regressão

# %% [markdown]
# Existem duas categorias principais de aprendizado supervisionado:
#
# * Classificação
# * Regressão
#
# **Classificação**
#
# A classificação lida com a previsão de variáveis pertencentes à categorias que representam classes ou rótulos discretos. Por exemplo, classificar e-mails como spam ou não spam, ou prever se um paciente tem alto risco de doença cardíaca. Os algoritmos de classificação aprendem a mapear os recursos de entrada para uma das classes predefinidas. Os exemplos que temos lidados até aqui pertencem a esta categoria. Em alguns casos, precisamos conhecer as probabilidades de uma varíavel pertencer à uma categoria ou não. Usa-se então a função *sigmoid*, ou *softmax* quando são várias categorias (ver o exemplo com a classificação de gênro segundo pesos e alturas).
#
# **Regressão**
#
# A regressão, por outro lado, lida com a previsão de variáveis-alvo contínuas, que representam valores numéricos. Por exemplo, prever o preço de uma casa com base em seu tamanho, localização e comodidades, ou prever as vendas de um produto. Os algoritmos de regressão aprendem a mapear os recursos de entrada para um valor numérico contínuo.
#
#     Regressão Linear :A regressão linear é um tipo de algoritmo  supervisionado que aprende com conjuntos de dados rotulados e mapeia os pontos de dados com funções lineares otimizadas, que podem ser usadas para previsão em novos conjuntos de dados. Ela calcula a relação linear entre a variável dependente e uma ou mais características independentes, ajustando uma equação linear com dados observados. Ela prevê as variáveis de saída contínuas com base na variável de entrada independente.
#     Por exemplo, se quisermos prever o preço de um imóvel, consideramos vários fatores, como idade do imóvel, distância da estrada principal, localização, área e número de cômodos. A regressão linear usa todos esses parâmetros para prever o preço do imóvel, pois considera uma relação linear entre todas essas características e o preço do imóvel.
#
#     Regressão Polinomial: A regressão polinomial é uma ferramenta poderosa para suavização de dados que pode ajudá -lo a fazer previsões, identificar tendências e muito mais.Envolve ajustar uma equação polinomial a um conjunto de pontos de dados, que podem ser usados para fazer previsões ou analisar tendências. É usada quando a relação entre as variáveis não é linear e os pontos de dados seguem uma tendência curvilínea. Por exemplo, uma curva em forma de U, ou uma relação cúbica.

# %% [markdown]
# Exemplo: Neste exemplo a força calculada sobre o peso ligado à uma mola é calculada como $F=mg$ e para cada peso (o qual cresce em intervalos de 50 g) é medida a distensão da mola $\Delta x$. Os valores são inseridos em um algoritmo de regressão linear ( neste caso, uma calculadora HP prime) e o ajuste é realizado.

# %% [markdown]
# <table>
#     <tr>
#       <td>
#       <img src='.\Mola1.png'width=400>
#       </td>
#       <td>
#       <img src='.\Mola2.png'width=400>
#       </td>
#       <td>
#       <img src='.\Mola3.png'width=400>
#       </td>
#      </tr>
# </table>

# %% [markdown]
# ### Exemplos com Keras/Tensorflow

# %% [markdown]
# ### a) Regressão Linear

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import backend

# %%
np.random.seed(0)
num_points = 100
X1 = np.linspace(0,1, num_points)
y1 = 4 + 3 * X1 + np.random.randn(num_points)/3

fig = plt.figure(figsize=(5, 5))
plt.scatter(X1, y1)
plt.xlabel('x', fontsize=14)
plt.ylabel('y', fontsize=14)
plt.show()

# %% [markdown]
# ### Uma Camada e Um Neurônio

# %%
backend.clear_session()
np.random.seed(0)
random.seed(0)
tf.random.set_seed(0)

model1 = Sequential()
model1.add(Dense(1, activation='linear', input_shape=(1,)))
model1.compile(optimizer='adam', loss='mse', metrics=['mse'])
model1.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Master\Desktop\WPy64-31180\python-3.11.8.amd64\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# C:\Users\Master\Desktop\WPy64-31180\python-3.11.8.amd64\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1)                   │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ![simple.png](attachment:aa528b76-530f-4abd-b79c-e6fe58ed753f.png)

# %%
history1 = model1.fit(X1, y1, epochs=1000, verbose=0,
                      batch_size=X1.shape[0])

# %%
X1_test = np.linspace(0,1, 1000)
yhat1 = model1.predict(X1_test)

fig = plt.figure(figsize=(5, 5))
plt.scatter(X1, y1, label="Train data")
plt.plot(X1_test, yhat1, color="red", label="Prediction")
plt.xlabel('x', fontsize=14)
plt.ylabel('y', fontsize=14)
plt.legend(loc="best", fontsize=11)
plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ### Rede com Múltiplas camadas

# %%
backend.clear_session()
np.random.seed(15)
random.seed(15)
tf.random.set_seed(15)

input_layer = Input(shape=(1,))
x = Dense(50, activation='relu')(input_layer)
output_layer = Dense(1, activation='linear')(x)
model2 = Model(inputs=input_layer, outputs=output_layer)

model2.compile(optimizer='adam', loss='mse', metrics=['mse'])
model2.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 1)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 50)                  │             100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 151 (604.00 B)
#  Trainable params: 151 (604.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ![MCamadas.png](attachment:044bb923-806b-4c3c-8c05-d3619281be08.png)

# %%
history2 = model2.fit(X1, y1, epochs=500, verbose=0,
                      batch_size=X1.shape[0])

# %%
X1_test = np.linspace(0,1, 1000)
yhat1 = model2.predict(X1_test)

fig = plt.figure(figsize=(5, 5))
plt.scatter(X1, y1, label="Train data", alpha=0.7)
plt.plot(X1_test, yhat1, color="red", label="Prediction")
plt.xlabel('x', fontsize=14)
plt.ylabel('y', fontsize=14)
plt.legend(loc="best", fontsize=11)
plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ### b) Recursão Quadrática (Não Linear)

# %%
np.random.seed(0)
num_points = 100
X2 = np.linspace(0,1, num_points)
y2 = -(X2-0.5)**2 + 0.25

fig = plt.figure(figsize=(5, 5))
plt.scatter(X2, y2)
plt.xlabel('x', fontsize=14)
plt.ylabel('y', fontsize=14)
plt.show()

# %% [markdown]
# ### Uma camada e um neurônio

# %%
backend.clear_session()
np.random.seed(0)
random.seed(0)
tf.random.set_seed(0)

model3 = Sequential()
model3.add(Dense(1, activation='linear', input_shape=(1,)))
model3.compile(optimizer='adam', loss='mse', metrics=['mse'])

# %%
history3 = model3.fit(X2, y2, epochs=500, verbose=0,
                      batch_size=X2.shape[0])

# %%
X2_test = np.linspace(0,1, 1000)
yhat2 = model3.predict(X2_test)

fig = plt.figure(figsize=(5, 5))
plt.scatter(X2, y2, label="Train data")
plt.plot(X2_test, yhat2, color="red", label="Prediction")
plt.xlabel('x', fontsize=14)
plt.ylabel('y', fontsize=14)
plt.legend(loc="best", fontsize=11)
plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ### Rede com Múltiplas camadas

# %%
backend.clear_session()
np.random.seed(15)
random.seed(15)
tf.random.set_seed(15)

input_layer = Input(shape=(1,))
x = Dense(100, activation='relu')(input_layer)
output_layer = Dense(1, activation='linear')(x)
model4 = Model(inputs=input_layer, outputs=output_layer)

model4.compile(optimizer='adam', loss='mse', metrics=['mse'])
model4.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 1)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 100)                 │             200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 301 (1.18 KB)
#  Trainable params: 301 (1.18 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history4 = model4.fit(X2, y2, epochs=1500, verbose=0,
                      batch_size=X2.shape[0])

# %%
X2_test = np.linspace(0,1, 1000)
yhat2 = model4.predict(X2_test)

fig = plt.figure(figsize=(5, 5))
plt.scatter(X2, y2, label="Train data", alpha=0.7)
plt.plot(X2_test, yhat2, color="red", label="Prediction")
plt.xlabel('x', fontsize=14)
plt.ylabel('y', fontsize=14)
plt.legend(loc="best", fontsize=11)
plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## Regressão Logística

# %% [markdown]
# A Regressão Logística é um dos algoritmos de aprendizado de máquina mais comuns. Ela pode ser usada para prever a probabilidade de ocorrência de um evento, como se um e-mail recebido é spam ou não, ou se um tumor é maligno ou não, com base em um determinado conjunto de dados rotulados.
#
# Devido à sua simplicidade, a regressão logística é frequentemente usada como base para a avaliação de outros modelos mais complexos.
#  O nome "Logística" vem da utilização da função *Sigmoid* para converter a combinação linear de um conjunto de dados em probabilidades, e não apenas classificar os dados em categorias. O método é classificado como regressão pelo fato que sua saída é um valor contínuo entre 0 e 1, embora seja normalmente usado como um classificador binário, escolhendo um valor limite (geralmente 0,5) e classificando entradas com probabilidade maior que o limite como classe positiva, e aquelas abaixo do limite como classe negativa.
